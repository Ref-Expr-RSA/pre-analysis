# %%
f=open('modifers.txt')

# %%
atr={}
less_than_ten=[]
for i in f:
    if int(str(i)[str(i).find('(')+1:str(i).find(')')])<10:
        less_than_ten.append(str(i)[:str(i).find('(')].strip('\n').strip(' '))
    else:
        atr[str(i)[:str(i).find('(')].strip('\n').strip(' ')]=int(str(i)[str(i).find('(')+1:str(i).find(')')])

# %%
for iter_atr in atr:
    print(iter_atr,atr[iter_atr])
# Out:
# right 470
# left 300
# white 258
# second 214
# on right 200
# on left 186
# middle 184
# front 184
# black 173
# bottom 144
# red 143
# top 140
# blue 140
# on the right 125
# in front 118
# on the left 106
# big 101
# brown 100
# first 95
# green 85
# third 72
# in back 68
# from left 65
# lower 64
# in middle 64
# from right 63
# closest 60
# yellow 57
# small 51
# dark 44
# partial 43
# in the middle 43
# large 36
# most 36
# in the back 35
# blurry 33
# gray 32
# in center 32
# back 31
# in background 31
# orange 30
# upper 29
# to the right 29
# far 28
# leftmost 28
# on top 28
# full 27
# empty 25
# in the front 25
# from bottom 25
# to the left 25
# main 24
# facing us 23
# tall 23
# pink 22
# on far left 21
# in foreground 21
# rightmost 20
# smaller 20
# on the far right 20
# in black 20
# close 19
# farthest 19
# little 19
# whole 18
# in red 18
# last 17
# on it 17
# on right side 17
# from the right 16
# on left side 16
# from front 16
# nearest 15
# from the left 15
# ...

# %%
for i in less_than_ten:
    print(i)
# Out:
# adult
# tallest
# open
# fourth
# to right
# in the center
# in the background
# at top
# of food
# on ground
# from top
# on the right side
# looking at us
# darker
# short
# colorful
# larger
# colored
# on bottom
# at the back
# in pink
# in it
# to us
# covered
# at left
# laying down
# taller
# baby
# sprinkled
# double
# smallest
# wooden
# old
# largest
# rightest
# visible
# polar
# from us
# in blue shirt
# at the bottom
# at right
# behind fence
# in front right
# in water
# on the left side
# looking at you
# on top left
# facing left
# hidden
# lowest
# long
# reddish
# seated
# powdered
# leftest
# solid
# beige
# right in front
# in hat
# on bike
# in bottom right corner
# on right front
# behind man
# in green
# on top right
# in black shirt
# on floor
# in yellow
# in rear
# on table
# at bottom
# in front middle
# in purple
# at the top
# in front of girl
# in air
# to the far right
# on right edge
# facing away
# looking at camera
# far left
# bending over
# ...

# %%
common_attributes = ['white','black','blue','green','red','brown','yellow',
    'small','large','silver','wooden','orange','gray','grey','metal','pink','tall',
    'long','dark']
common_attributes.append('big')
common_attributes.append('partial')

common_attributes.append('full')
common_attributes.append('empty')
common_attributes.append('blurry')
common_attributes.append('main')

common_attributes.append('little')
common_attributes.append('whole')
common_attributes.append('half')
common_attributes.append('old')
common_attributes.append('visible')
common_attributes.append('light')
common_attributes.append('striped')
common_attributes.append('purple')

# %%
common_location=['center','right','top','left','middle','back','bottom','front']

# %%
selected_attribute=[]
selected_location=[]
# common_location=['center','right','top','left','middle','back','bottom']
other=[]
for iter_atr in atr:
#     print(iter_atr)
    in_attr=False
    if iter_atr in common_attributes:
#     for itr_ca in common_attributes:
#         if iter_atr.find(itr_ca)!=-1:
            selected_attribute.append(iter_atr)
            in_attr=True
            continue
    if in_attr==False:
        if iter_atr.find('center')!=-1\
        or iter_atr.find('right')!=-1\
        or iter_atr.find('top')!=-1 \
        or iter_atr.find('left')!=-1\
        or iter_atr.find('middle')!=-1\
        or iter_atr.find('back')!=-1\
        or iter_atr.find('bottom')!=-1\
        or iter_atr.find('front')!=-1:
            selected_location.append(iter_atr)
        else:
            other.append(iter_atr)

# %%
for i in selected_attribute:
    print(i)
# Out:
# white
# black
# red
# blue
# big
# brown
# green
# yellow
# small
# dark
# partial
# large
# blurry
# gray
# orange
# full
# empty
# main
# tall
# pink
# little
# whole
# silver
# half
# striped
# purple
# light

# %%
for i in selected_location:
    print(i)
# Out:
# right
# left
# on right
# on left
# middle
# front
# bottom
# top
# on the right
# in front
# on the left
# in back
# from left
# in middle
# from right
# in the middle
# in the back
# in center
# back
# in background
# to the right
# leftmost
# on top
# in the front
# from bottom
# to the left
# on far left
# rightmost
# on the far right
# on right side
# from the right
# on left side
# from front
# from the left
# on the bottom
# on far right
# to left
# on the far left
# on bottom right

# %%
for i in other:
    print(i)
# print(other)
# ??deal with comparison word
# 'short', 'colorful', 'tan', 'maroon', 'clear', 'sitting', 'eaten', 'raised', 'ripe', 'spotted','bending over', 'lying down','headless',/
#  'sitting down','round', 'plain'，'tiny', 'cute', 'fuzzy','upside'， 'pale', 'bad','parked', 'kneeling down', 'facing forward'

# 'rear',
# Out:
# second
# first
# third
# lower
# closest
# most
# upper
# far
# facing us
# in foreground
# close
# farthest
# last
# on it
# nearest
# furthest
# on far
# with head
# near us
